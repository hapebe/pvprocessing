# %%
# !pip install pvlib pandas pytz matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pvlib
#   Downloading pvlib-0.13.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting pytz
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting numpy>=1.21.2 (from pvlib)
#   Downloading numpy-2.4.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/lib/python3.14/site-packages (from pvlib) (2.32.5)
# Collecting scipy>=1.7.2 (from pvlib)
#   Downloading scipy-1.16.3-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting h5py (from pvlib)
#   Downloading h5py-3.15.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.14/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/lib/python3.14/site-packages (from requests->pvlib) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.14/site-packages (from requests->pvlib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.14/site-packages (from requests->pvlib) (2.6.2)
# Downloading pvlib-0.13.1-py3-none-any.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 49.9 kB/s eta 0:00:00m eta 0:00:050:15:21
# Downloading pandas-2.3.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 51.1 kB/s eta 0:00:000:00:060:00:11:23
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading numpy-2.4.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 47.5 kB/s eta 0:00:00m eta 0:00:030:14:20
# Downloading scipy-1.16.3-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 43.5 kB/s eta 0:00:00m eta 0:00:020:00:24
# Downloading h5py-3.15.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 42.7 kB/s eta 0:00:000:00:030:00:09:15
# Installing collected packages: pytz, numpy, scipy, pandas, h5py, pvlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [pvlib]━━━━━ 5/6 [pvlib][h5py]]
# Successfully installed h5py-3.15.1 numpy-2.4.0 pandas-2.3.3 pvlib-0.13.1 pytz-2025.2 scipy-1.16.3

# %%
import pandas as pd
import pvlib
import pytz

# %%
# --- Location ---
latitude = 52.52       # example: Berlin
longitude = 13.405
timezone = "Etc/UTC"
# timezone = "Europe/Berlin"

# --- Time range ---
year = 2025

start = pd.Timestamp(f"{year}-01-01 00:00:00", tz=timezone)
end   = pd.Timestamp(f"{year}-12-31 23:59:00", tz=timezone)

# 1-minute resolution
times = pd.date_range(start=start, end=end, freq="10min")

# %%
# Create location object
location = pvlib.location.Location(latitude, longitude, tz=timezone)

# Calculate solar position
solar_position = location.get_solarposition(times)

solar_position.head()
# Out:
#                            apparent_zenith      zenith  apparent_elevation  \
# 2025-01-01 00:00:00+00:00       148.960089  148.960089          -58.960089
# 2025-01-01 00:10:00+00:00       148.318295  148.318295          -58.318295
# 2025-01-01 00:20:00+00:00       147.577815  147.577815          -57.577815
# 2025-01-01 00:30:00+00:00       146.745798  146.745798          -56.745798
# 2025-01-01 00:40:00+00:00       145.829564  145.829564          -55.829564
#
#                            elevation    azimuth  equation_of_time
# 2025-01-01 00:00:00+00:00 -58.960089  22.813240         -3.438820
# 2025-01-01 00:10:00+00:00 -58.318295  27.058922         -3.442108
# 2025-01-01 00:20:00+00:00 -57.577815  31.163917         -3.445395
# 2025-01-01 00:30:00+00:00 -56.745798  35.119843         -3.448683
# 2025-01-01 00:40:00+00:00 -55.829564  38.922509         -3.451969

# %%
sun_data = solar_position[["azimuth", "elevation"]].copy()

sun_data.head()
# Out:
#                              azimuth  elevation
# 2025-01-01 00:00:00+00:00  22.813240 -58.960089
# 2025-01-01 00:10:00+00:00  27.058922 -58.318295
# 2025-01-01 00:20:00+00:00  31.163917 -57.577815
# 2025-01-01 00:30:00+00:00  35.119843 -56.745798
# 2025-01-01 00:40:00+00:00  38.922509 -55.829564

# %% [markdown]
# *optional:*
#
# Remove nighttime values (sun below horizon):

# %%
sun_data = sun_data[sun_data["elevation"] > 0]

# %%
sun_data.to_csv("sun_position_10min.csv")

# %%
import matplotlib.pyplot as plt

# Plot one day
day = sun_data.loc["2025-06-21"]

plt.figure(figsize=(10,4))
plt.plot(day.index, day["elevation"])
plt.ylabel("Solar elevation (°)")
plt.title("Solar elevation on summer solstice")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 # Plot one day
#       4 day = sun_data.loc["2025-06-21"]
#
# ModuleNotFoundError: No module named 'matplotlib'
